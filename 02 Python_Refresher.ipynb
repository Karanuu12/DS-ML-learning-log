# %%
name = "Karan"

# %%
name
# Out:
# 'Karan'

# %%
name.upper()
# Out:
# 'KARAN'

# %%
name.endswith("an")
# Out:
# True

# %%
name.count("a")
surname = musale""
# Out:
# 2

# %%
name[0:3]
# Out:
# 'Kar'

# %%
name[-4:]
# Out:
# 'aran'

# %%
print(str.lower(name))
str.upper(name)
# Out:
# karan
# 'KARAN'

# %%
print(len(surname))
# Out:
# 6

# %%
fruits = "apple, banana, guava, grapes, watermelon, strawberry"
lst = fruits.split(",")
print(lst)
# Out:
# ['apple', ' banana', ' guava', ' grapes', ' watermelon', ' strawberry']

# %%
name.join(lst) #apple + Karan + banana + Karan + guava + Karan + grapes + Karan + watermelon + Karan + strawberry
# Out:
# 'appleKaran bananaKaran guavaKaran grapesKaran watermelonKaran strawberry'
