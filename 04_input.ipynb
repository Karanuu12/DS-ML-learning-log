# %% [markdown]
# # Taking Input from user

# %%
a = input("Enter a value for a :" ) #it takes user input as string
# Out:
# Enter a value for a : 13

# %%
b = input("Enter a value for b :" )
# Out:
# Enter a value for b : 7

# %%
a + b # '137' because string concatenation
# Out:
# '137'

# %%
int(a) + int(b)  #type casting from string to int and then addition
# Out:
# 20
