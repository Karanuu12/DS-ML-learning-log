# %%
def avg(a,b):
    a = int(input("Enter a value of a : "))
    b = int(input("Enter a value of b : "))
    return (a+b)/2

# %%
print(avg(a,b))
# Out:
# Enter a value of a :  23
# Enter a value of b :  45
# 34.0

# %%
def add(a, b=10): #default arguement at end
    return a+b

# %%
def greet():
    print("Hello Good Morning")

# %%
greet()
# Out:
# Hello Good Morning

# %% [markdown]
# # Formatted Strings

# %%
Name = "Karan"
age = "20"
print("My name is {} and i am {} years old" .format(Name, age))
# Out:
# My name is Karan and i am 20 years old

# %%
print("{0} is learning {}".format("Karan", "python"))
# Out:
# Alice is learning Python
# Alice is learning Python
