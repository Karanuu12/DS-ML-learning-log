# %%
def avg(a,b):
    a = int(input("Enter a value of a : "))
    b = int(input("Enter a value of b : "))
    return (a + b) / 2

# %%
print(avg())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 print(avg())
#
# TypeError: avg() missing 2 required positional arguments: 'a' and 'b'

# %%
def add(a, b=10): #default arguement at end
    return a+b

# %%
def greet(name):
    print(f"Hello {name}")

# %%
greet("Madhura")
# Out:
# Hello Madhura

# %% [markdown]
# # Formatted Strings

# %%
Name = "Karan"
age = "20"
print("My name is {} and i am {} years old" .format(Name, age)) 
print(f"My name is {Name} and i am {age} years old") #Same Output , different method tu use Formatted String
# Out:
# My name is Karan and i am 20 years old
# My name is Karan and i am 20 years old

# %%
prog = "python"
print("{0} is learning {1}".format("Karan", "python"))
print(f"{Name} is Learning {prog}")#Same Output , different method tu use Formatted String
# Out:
# Karan is learning python
# Karan is Learning python
