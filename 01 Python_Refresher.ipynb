# %% [markdown]
# # Python Variables and Data Types
#
# Author: Karan Musale
#
# Topic:
# Variables
# Data Types
# Typecasting

# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
name = "Karan"

# %%
print(name)
# Out:
# Karan

# %%
c = str(25)        # "25"
print(c)
# Out:
# 25

# %%
lst = list("abc")  # ['a', 'b', 'c']

# %%
print(lst)
# Out:
# ['a', 'b', 'c']
