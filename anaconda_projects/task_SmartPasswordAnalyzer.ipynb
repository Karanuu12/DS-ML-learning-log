# %%
def register():
    
    name = input("Enter Name: ").title()
    
    
    age = input("Enter your age: ")
    if not(age.isdigit()):
        print("Enter Valid Age!")
        return
    elif (int(age)<13):
        print('Age must be "13+"!. Registration Rejected')
        return
    elif not(1<int(age)<111):
        print("Enter Valid Age!")
        return
    else:
        pass

        
    user = input("Enter Username: ").lower()
    if (" "in user):
        print("Username cannot contain blank spaces!")
        return
    elif (len(user)<5):
        print("Username must be atleast 5 digit long.")
        return
    elif (user == "admin"):
        print("Username cannot be Admin!")
        return
    else:
        pass
    
   
    passw = str(input("Enter Password: "))




    

    print("\t==== Registration Result ====\n")
    
    print(name)
    
    print(age)
    
    if (13<=int(age)<=17):
        print("Account Type: Minor Account")
    elif(18<=int(age)<=60):
        print("Account Type: Adult Account")
    else:
        print("Account Type: Senior Account")

        
    print(user)

# %%
register()
# Out:
# Enter Name:  kAraN muSALE
# Enter your age:  65
# Enter Username:  KARAN
# Enter Password:  KaranTheDon029
# 	==== Registration Result ====
#
# Karan Musale
# 65
# Account Type: Senior Account
# karan
